# %% [markdown]
# # Slice Time Correction
# Unlike a photograph, in which the entire picture is taken in a single moment, an fMRI volume is acquired in slices. Each of these slices takes time to acquire - from tens to hundreds of milliseconds.
#
# The two most commonly used methods for creating volumes are sequential and interleaved slice acquisition. We used "interleaved" method. The slice-timing correction can lead to significant increases in statistical power for studies with longer TRs (e.g., 2s or longer).
#
# Here we only applied slice time correction on the resting-State data since they were recorded in the single shot manner.
#
#
# -----------------------------------------------------------
# Script written by Sepideh Tabrik & Mehdi Behroozi
# <br>
# Biopsychology,
# <br>
# Ruhr-University Bochum, Bochum, Germany
# <br>
# (2022.03)
#
# -----------------------------------------------------------

# %%
import glob
import os
import subprocess

data_path = '/mnt/d/Data/Human/ObjectCategorization/analysis2'
bold_dirs = glob.glob('%s/sub*/ses-*/func/*rest*/bold_mcf.nii.gz'%(data_path))
TR = 2.5
acquisitionType = 'odd'

for curr_bold in bold_dirs:
    sub_dir = os.path.dirname(curr_bold)
    print('Currect direcotry is: %s'%(sub_dir))

    # change directory to the res_dir 
    print('\t 1) Changing the working directory to %s'%(sub_dir))
    os.chdir(sub_dir)
    
    #slice time correction

    print('\t 2) Slice Time Correction using "slicetimer" function of FSL ...')
    os.system("slicetimer -i bold_mcf --out=bold_mcf_st -r %s --%s"%(TR,acquisitionType))
    #os.system("fslmaths bold_mcf_st -Tmean mean_func")
# Out:
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-01/ses-01/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-01/ses-01/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-01/ses-01/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-01/ses-01/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-01/ses-02/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-01/ses-02/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-01/ses-02/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-01/ses-02/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-02/ses-01/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-02/ses-01/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-02/ses-01/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-02/ses-01/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-02/ses-02/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-02/ses-02/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-02/ses-02/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-02/ses-02/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-03/ses-01/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-03/ses-01/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-03/ses-01/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-03/ses-01/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-03/ses-02/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-03/ses-02/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-03/ses-02/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-03/ses-02/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-04/ses-01/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-04/ses-01/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-04/ses-01/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-04/ses-01/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-04/ses-02/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-04/ses-02/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-04/ses-02/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-04/ses-02/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-05/ses-01/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-05/ses-01/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-05/ses-01/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-05/ses-01/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-05/ses-02/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-05/ses-02/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-05/ses-02/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-05/ses-02/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-06/ses-01/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-06/ses-01/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-06/ses-01/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-06/ses-01/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-06/ses-02/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-06/ses-02/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-06/ses-02/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-06/ses-02/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-07/ses-01/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-07/ses-01/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-07/ses-01/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-07/ses-01/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-07/ses-02/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-07/ses-02/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-07/ses-02/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-07/ses-02/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-08/ses-01/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-08/ses-01/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-08/ses-01/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-08/ses-01/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-08/ses-02/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-08/ses-02/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-08/ses-02/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-08/ses-02/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-09/ses-01/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-09/ses-01/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-09/ses-01/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-09/ses-01/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-09/ses-02/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-09/ses-02/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-09/ses-02/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-09/ses-02/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-10/ses-01/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-10/ses-01/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-10/ses-01/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-10/ses-01/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-10/ses-02/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-10/ses-02/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-10/ses-02/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-10/ses-02/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-11/ses-01/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-11/ses-01/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-11/ses-01/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-11/ses-01/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-11/ses-02/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-11/ses-02/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-11/ses-02/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-11/ses-02/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-12/ses-01/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-12/ses-01/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-12/ses-01/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-12/ses-01/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-12/ses-02/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-12/ses-02/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-12/ses-02/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-12/ses-02/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-13/ses-01/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-13/ses-01/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-13/ses-01/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-13/ses-01/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-13/ses-02/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-13/ses-02/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-13/ses-02/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-13/ses-02/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-14/ses-01/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-14/ses-01/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-14/ses-01/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-14/ses-01/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-14/ses-02/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-14/ses-02/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-14/ses-02/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-14/ses-02/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-15/ses-01/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-15/ses-01/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-15/ses-01/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-15/ses-01/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-15/ses-02/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-15/ses-02/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-15/ses-02/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-15/ses-02/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-16/ses-01/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-16/ses-01/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-16/ses-01/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-16/ses-01/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-16/ses-02/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-16/ses-02/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-16/ses-02/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-16/ses-02/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-17/ses-01/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-17/ses-01/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-17/ses-01/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-17/ses-01/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-17/ses-02/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-17/ses-02/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-17/ses-02/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-17/ses-02/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-18/ses-01/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-18/ses-01/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-18/ses-01/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-18/ses-01/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-18/ses-02/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-18/ses-02/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-18/ses-02/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-18/ses-02/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-19/ses-01/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-19/ses-01/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-19/ses-01/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-19/ses-01/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-19/ses-02/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-19/ses-02/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-19/ses-02/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-19/ses-02/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-20/ses-01/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-20/ses-01/func/restpost
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-20/ses-01/func/restpre
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-20/ses-01/func/restpre
# 	 2) Slice Time Correction using "slicetimer" function of FSL ...
# Currect direcotry is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-20/ses-02/func/restpost
# 	 1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub