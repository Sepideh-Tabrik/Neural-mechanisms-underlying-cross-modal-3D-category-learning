# %% [markdown]
# # Evaluate the motion artifacts of BOLD data
# This measure indexes the movement of the head from one volume to the next, and is calculated as the sum of the absolute values of the differentiated realignment estimates (by backwards differences) at every timepoint.
# <br>
# You need to adjust the threshould for number of affected volumes and threshould for absolut value for FD.
#
# -----------------------------------------------------------
# Script written by Sepideh Tabri& Mehdi Behroozi
# <br>
# Biopsychology,
# <br>
# Ruhr-University Bochum, Bochum, Germany
# <br>
# (2022.03)
#
# -----------------------------------------------------------

# %%
import os
import glob
import shutil
from pathlib import Path

# Absolute threshold value for affected volume by motion
thresh = 0.9  # (edit here)

# Set data path
data_path = Path("/mnt/d/Data/Human/ObjectCategorization/analysis2")  # (edit here)

# Find bold files
bold_files = glob.glob(f"{data_path}/sub*/ses-*/func/*rest*.nii.gz")

for curr_bold in bold_files:
    curr_bold_path = Path(curr_bold)
    print(f"Current data is: {curr_bold_path.name}")

    exp_name = curr_bold_path.stem.split("_")[-2].split("-")[-1]
    cur_dir = curr_bold_path.parent / exp_name
    print(cur_dir)

    # Create results directory if it doesn't exist
    if not cur_dir.exists():
        print("\t 1) Creating 'results' directory ...")
        cur_dir.mkdir(parents=True)
    else:
        print("\t 1) 'results' directory exists.")

    # Create motion_assess directory
    motion_assess_dir = cur_dir / "motion_assess"
    
    if not motion_assess_dir.exists():
        print(f"\t 2) Creating {motion_assess_dir} directory ...")
        motion_assess_dir.mkdir()
    else:
        print(f"\t 2) {motion_assess_dir} directory exists! Deleting old and creating new directory ...")
        shutil.rmtree(motion_assess_dir)
        motion_assess_dir.mkdir()

    # Running fsl_motion_outliers
    print(f"\t 3) Running fsl_motion_outliers with threshold of {thresh} ...\n")
    cmd = (
        f"fsl_motion_outliers -i {curr_bold} "
        f"-o {motion_assess_dir}/confound.txt --fd --thresh={thresh} "
        f"-s {motion_assess_dir}/fd_data.txt -p {motion_assess_dir}/fd_plot "
        f"-v > {motion_assess_dir}/outlier_output.txt"
    )
    os.system(cmd)

    # Create an empty placeholder file if confound.txt is missing
    confound_file = motion_assess_dir / "confound.txt"
    if not confound_file.exists():
        confound_file.touch()
# Out:
# Current data is: sub-01_ses-01_task-restpost_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-01/ses-01/func/restpost
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-01/ses-01/func/restpost/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-01_ses-01_task-restpre_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-01/ses-01/func/restpre
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-01/ses-01/func/restpre/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-01_ses-02_task-restpost_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-01/ses-02/func/restpost
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-01/ses-02/func/restpost/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-01_ses-02_task-restpre_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-01/ses-02/func/restpre
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-01/ses-02/func/restpre/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-02_ses-01_task-restpost_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-02/ses-01/func/restpost
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-02/ses-01/func/restpost/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-02_ses-01_task-restpre_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-02/ses-01/func/restpre
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-02/ses-01/func/restpre/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-02_ses-02_task-restpost_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-02/ses-02/func/restpost
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-02/ses-02/func/restpost/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-02_ses-02_task-restpre_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-02/ses-02/func/restpre
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-02/ses-02/func/restpre/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-03_ses-01_task-restpost_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-03/ses-01/func/restpost
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-03/ses-01/func/restpost/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-03_ses-01_task-restpre_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-03/ses-01/func/restpre
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-03/ses-01/func/restpre/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-03_ses-02_task-restpost_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-03/ses-02/func/restpost
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-03/ses-02/func/restpost/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-03_ses-02_task-restpre_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-03/ses-02/func/restpre
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-03/ses-02/func/restpre/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-04_ses-01_task-restpost_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-04/ses-01/func/restpost
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-04/ses-01/func/restpost/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-04_ses-01_task-restpre_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-04/ses-01/func/restpre
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-04/ses-01/func/restpre/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-04_ses-02_task-restpost_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-04/ses-02/func/restpost
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-04/ses-02/func/restpost/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-04_ses-02_task-restpre_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-04/ses-02/func/restpre
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-04/ses-02/func/restpre/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-05_ses-01_task-restpost_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-05/ses-01/func/restpost
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-05/ses-01/func/restpost/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-05_ses-01_task-restpre_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-05/ses-01/func/restpre
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-05/ses-01/func/restpre/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-05_ses-02_task-restpost_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-05/ses-02/func/restpost
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-05/ses-02/func/restpost/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-05_ses-02_task-restpre_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-05/ses-02/func/restpre
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-05/ses-02/func/restpre/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-06_ses-01_task-restpost_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-06/ses-01/func/restpost
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-06/ses-01/func/restpost/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-06_ses-01_task-restpre_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-06/ses-01/func/restpre
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-06/ses-01/func/restpre/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-06_ses-02_task-restpost_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-06/ses-02/func/restpost
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-06/ses-02/func/restpost/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-06_ses-02_task-restpre_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-06/ses-02/func/restpre
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-06/ses-02/func/restpre/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
# Current data is: sub-07_ses-01_task-restpost_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-07/ses-01/func/restpost
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-07/ses-01/func/restpost/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-07_ses-01_task-restpre_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-07/ses-01/func/restpre
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-07/ses-01/func/restpre/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-07_ses-02_task-restpost_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-07/ses-02/func/restpost
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-07/ses-02/func/restpost/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-07_ses-02_task-restpre_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-07/ses-02/func/restpre
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-07/ses-02/func/restpre/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-08_ses-01_task-restpost_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-08/ses-01/func/restpost
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-08/ses-01/func/restpost/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-08_ses-01_task-restpre_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-08/ses-01/func/restpre
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-08/ses-01/func/restpre/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-08_ses-02_task-restpost_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-08/ses-02/func/restpost
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-08/ses-02/func/restpost/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-08_ses-02_task-restpre_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-08/ses-02/func/restpre
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-08/ses-02/func/restpre/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-09_ses-01_task-restpost_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-09/ses-01/func/restpost
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-09/ses-01/func/restpost/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-09_ses-01_task-restpre_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-09/ses-01/func/restpre
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-09/ses-01/func/restpre/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-09_ses-02_task-restpost_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-09/ses-02/func/restpost
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-09/ses-02/func/restpost/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-09_ses-02_task-restpre_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-09/ses-02/func/restpre
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-09/ses-02/func/restpre/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-10_ses-01_task-restpost_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-10/ses-01/func/restpost
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-10/ses-01/func/restpost/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-10_ses-01_task-restpre_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-10/ses-01/func/restpre
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-10/ses-01/func/restpre/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-10_ses-02_task-restpost_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-10/ses-02/func/restpost
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-10/ses-02/func/restpost/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-10_ses-02_task-restpre_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-10/ses-02/func/restpre
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-10/ses-02/func/restpre/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-11_ses-01_task-restpost_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-11/ses-01/func/restpost
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-11/ses-01/func/restpost/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-11_ses-01_task-restpre_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-11/ses-01/func/restpre
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-11/ses-01/func/restpre/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub
ses-02/func/restpost/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-80_ses-02_task-restpre_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-80/ses-02/func/restpre
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-80/ses-02/func/restpre/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-81_ses-01_task-restpost_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-81/ses-01/func/restpost
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-81/ses-01/func/restpost/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-81_ses-01_task-restpre_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-81/ses-01/func/restpre
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-81/ses-01/func/restpre/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-81_ses-02_task-restpost_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-81/ses-02/func/restpost
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-81/ses-02/func/restpost/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-81_ses-02_task-restpre_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-81/ses-02/func/restpre
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-81/ses-02/func/restpre/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-82_ses-01_task-restpost_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-82/ses-01/func/restpost
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-82/ses-01/func/restpost/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-82_ses-01_task-restpre_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-82/ses-01/func/restpre
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-82/ses-01/func/restpre/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-82_ses-02_task-restpost_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-82/ses-02/func/restpost
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-82/ses-02/func/restpost/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-82_ses-02_task-restpre_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-82/ses-02/func/restpre
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-82/ses-02/func/restpre/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-83_ses-01_task-restpost_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-83/ses-01/func/restpost
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-83/ses-01/func/restpost/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-83_ses-01_task-restpre_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-83/ses-01/func/restpre
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-83/ses-01/func/restpre/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-83_ses-02_task-restpre_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-83/ses-02/func/restpre
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-83/ses-02/func/restpre/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-84_ses-01_task-restpost_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-84/ses-01/func/restpost
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-84/ses-01/func/restpost/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-84_ses-01_task-restpre_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-84/ses-01/func/restpre
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-84/ses-01/func/restpre/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...
#
# Current data is: sub-84_ses-02_task-restpre_bold.nii.gz
# /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-84/ses-02/func/restpre
# 	 1) Creating 'results' directory ...
# 	 2) Creating /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-84/ses-02/func/restpre/motion_assess directory ...
# 	 3) Running fsl_motion_outliers with threshold of 0.9 ...

# %% [markdown]
# ## plot Framewise Displasment Results
# The results for single subjects will be ploted

# %%
# %matplotlib inline

from IPython.display import display, Image
import matplotlib.pyplot as plt
import glob
from pathlib import Path

# Define data path
data_path = Path("/mnt/d/Data/Human/ObjectCategorization/analysis2")

# Find all fd_plot.png files
FD_files = list(data_path.glob("sub*/ses-0*/func/rest*/motion_assess/fd_plot.png"))

# Process each image file
if FD_files:
    for curr_FD in FD_files:
        curr_FD_path = Path(curr_FD)
        
        # Extract sub, session, func folder names dynamically
        sub = curr_FD_path.parts[-6]
        session = curr_FD_path.parts[-5]
        func = curr_FD_path.parts[-3]

        print(f"{sub}/{session}/{func}")

        # Show the plot
        plt.show()

        # Display the image
        display(Image(filename=str(curr_FD_path)))

else:
    print("No fd_plot.png files found.")
# Out:
# sub-01/ses-01/restpost
# sub-01/ses-01/restpre
# sub-01/ses-02/restpost
# sub-01/ses-02/restpre
# sub-02/ses-01/restpost
# sub-02/ses-01/restpre
# sub-02/ses-02/restpost
# sub-02/ses-02/restpre
# sub-03/ses-01/restpost
# sub-03/ses-01/restpre
# sub-03/ses-02/restpost
# sub-03/ses-02/restpre
# sub-04/ses-01/restpost
# sub-04/ses-01/restpre
# sub-04/ses-02/restpost
# sub-04/ses-02/restpre
# sub-05/ses-01/restpost
# sub-05/ses-01/restpre
# sub-05/ses-02/restpost
# sub-05/ses-02/restpre
# sub-06/ses-01/restpost
# sub-06/ses-01/restpre
# sub-06/ses-02/restpost
# sub-06/ses-02/restpre
# sub-07/ses-01/restpost
# sub-07/ses-01/restpre
# sub-07/ses-02/restpost
# sub-07/ses-02/restpre
# sub-08/ses-01/restpost
# sub-08/ses-01/restpre
# sub-08/ses-02/restpost
# sub-08/ses-02/restpre
# sub-09/ses-01/restpost
# sub-09/ses-01/restpre
# sub-09/ses-02/restpost
# sub-09/ses-02/restpre
# sub-10/ses-01/restpost
# sub-10/ses-01/restpre
# sub-10/ses-02/restpost
# sub-10/ses-02/restpre
# sub-11/ses-01/restpost
# sub-11/ses-01/restpre
# sub-11/ses-02/restpost
# sub-11/ses-02/restpre
# sub-12/ses-01/restpost
# sub-12/ses-01/restpre
# sub-12/ses-02/restpost
# sub-12/ses-02/restpre
# sub-13/ses-01/restpost
# sub-13/ses-01/restpre
# sub-13/ses-02/restpost
# sub-13/ses-02/restpre
# sub-14/ses-01/restpost
# sub-14/ses-01/restpre
# sub-68/ses-02/restpre
# sub-69/ses-01/restpost
# sub-69/ses-01/restpre
# sub-69/ses-02/restpost
# sub-69/ses-02/restpre
# sub-70/ses-01/restpost
# sub-70/ses-01/restpre
# sub-70/ses-02/restpost
# sub-70/ses-02/restpre
# sub-71/ses-01/restpost
# sub-71/ses-01/restpre
# sub-71/ses-02/restpost
# sub-71/ses-02/restpre
# sub-72/ses-01/restpost
# sub-72/ses-01/restpre
# sub-72/ses-02/restpost
# sub-72/ses-02/restpre
# sub-73/ses-01/restpost
# sub-73/ses-01/restpre
# sub-73/ses-02/restpost
# sub-73/ses-02/restpre
# sub-74/ses-01/restpost
# sub-74/ses-01/restpre
# sub-74/ses-02/restpost
# sub-74/ses-02/restpre
# sub-75/ses-01/restpost
# sub-75/ses-01/restpre
# sub-75/ses-02/restpost
# sub-75/ses-02/restpre
# sub-76/ses-01/restpost
# sub-76/ses-01/restpre
# sub-76/ses-02/restpost
# sub-76/ses-02/restpre
# sub-77/ses-01/restpost
# sub-77/ses-01/restpre
# sub-77/ses-02/restpost
# sub-77/ses-02/restpre
# sub-78/ses-01/restpost
# sub-78/ses-01/restpre
# sub-78/ses-02/restpost
# sub-78/ses-02/restpre
# sub-79/ses-01/restpost
# sub-79/ses-01/restpre
# sub-79/ses-02/restpost
# sub-79/ses-02/restpre
# sub-80/ses-01/restpost
# sub-80/ses-01/restpre
# sub-80/ses-02/restpost
# sub-80/ses-02/restpre
# sub-81/ses-01/restpost
# sub-81/ses-01/restpre
# sub-81/ses-02/restpost
# sub-81/ses-02/restpre
# sub-82/ses-01/restpost
# sub-82/ses-01/restpre
# sub-82/ses-02/restpost
# sub-82/ses-02/restpre
# sub-83/ses-01/restpost
# sub-83/ses-01/restpre
# sub-83/ses-02/restpre
# sub-84/ses-01/restpost
# sub-84/ses-01/restpre
# sub-84/ses-02/restpre

# %% [markdown]
# # Plot Histogram
# This code will pull FD data from all subjects and plot the histogram

# %%
# Import necessary libraries
import glob
import matplotlib.pyplot as plt
import os
from pathlib import Path

# Define data path
data_path = Path("/mnt/d/Data/Human/ObjectCategorization/analysis2")

# Find all fd_data.txt files
FD_files = list(data_path.glob("sub*/ses-*/func/rest*/motion_assess/fd_data.txt"))

# Initialize list to store framewise displacement data
FD_data = []

# Read and process data from files
for cur_FD in FD_files:
    with open(cur_FD, "r") as f:
        FD_data.extend(float(line.strip()) for line in f if line.strip())  # Filters valid numeric values

# Plot histogram
plt.figure(figsize=(8, 6))
plt.hist(FD_data, bins=500, orientation="horizontal", color="skyblue", edgecolor="black")
plt.ylabel("Framewise displacement (mm)")
plt.xlabel("Volume count")

# Apply styling
plt.style.use("seaborn-bright")

# Optional: Save plots
# output_dir = data_path / "motion_parameters"
# output_dir.mkdir(exist_ok=True)  # Ensure output directory exists
# plt.savefig(output_dir / "FD.svg", format="svg", dpi=1200)
# plt.savefig(output_dir / "FD.png")

# Show the plot
plt.show()

# %% [markdown]
# # Finding number of affected volumes for each run

# %%
import glob
import matplotlib.pyplot as plt
from pathlib import Path

# Define data path
data_path = Path("/mnt/d/Data/Human/ObjectCategorization/analysis2")

# Find all fd_data.txt files
FD_files = list(data_path.glob("sub*/ses-*/func/rest*/motion_assess/fd_data.txt"))

# Define motion threshold
thresh = 0.9  # Absolute threshold value for affected volume by motion (edit here)

# Define function to compute length above threshold
def length_of_list(data, threshold):
    return sum(1 for value in data if value > threshold)

# Process each file
for cur_FD in FD_files:
    FD_data = []

    # Read and process data
    with open(cur_FD, "r") as f:
        FD_data = [float(line.strip()) for line in f if line.strip()]  # Removes empty lines and converts values

    # Extract relevant metadata from path
    cur_FD_path = Path(cur_FD)
    sub = cur_FD_path.parts[-6]
    session = cur_FD_path.parts[-5]
    motion_assess = cur_FD_path.parts[-3]

    # Print structured output
    print(f"{sub}/{session}/{motion_assess} \t --->> \t {length_of_list(FD_data, thresh)}")
# Out:
# sub-01/ses-01/restpost 	 --->> 	 0
# sub-01/ses-01/restpre 	 --->> 	 0
# sub-01/ses-02/restpost 	 --->> 	 1
# sub-01/ses-02/restpre 	 --->> 	 0
# sub-02/ses-01/restpost 	 --->> 	 0
# sub-02/ses-01/restpre 	 --->> 	 0
# sub-02/ses-02/restpost 	 --->> 	 0
# sub-02/ses-02/restpre 	 --->> 	 0
# sub-03/ses-01/restpost 	 --->> 	 0
# sub-03/ses-01/restpre 	 --->> 	 0
# sub-03/ses-02/restpost 	 --->> 	 0
# sub-03/ses-02/restpre 	 --->> 	 0
# sub-04/ses-01/restpost 	 --->> 	 0
# sub-04/ses-01/restpre 	 --->> 	 0
# sub-04/ses-02/restpost 	 --->> 	 0
# sub-04/ses-02/restpre 	 --->> 	 0
# sub-05/ses-01/restpost 	 --->> 	 0
# sub-05/ses-01/restpre 	 --->> 	 0
# sub-05/ses-02/restpost 	 --->> 	 0
# sub-05/ses-02/restpre 	 --->> 	 0
# sub-06/ses-01/restpost 	 --->> 	 0
# sub-06/ses-01/restpre 	 --->> 	 0
# sub-06/ses-02/restpost 	 --->> 	 0
# sub-06/ses-02/restpre 	 --->> 	 0
# sub-07/ses-01/restpost 	 --->> 	 0
# sub-07/ses-01/restpre 	 --->> 	 0
# sub-07/ses-02/restpost 	 --->> 	 0
# sub-07/ses-02/restpre 	 --->> 	 0
# sub-08/ses-01/restpost 	 --->> 	 0
# sub-08/ses-01/restpre 	 --->> 	 0
# sub-08/ses-02/restpost 	 --->> 	 0
# sub-08/ses-02/restpre 	 --->> 	 0
# sub-09/ses-01/restpost 	 --->> 	 0
# sub-09/ses-01/restpre 	 --->> 	 0
# sub-09/ses-02/restpost 	 --->> 	 0
# sub-09/ses-02/restpre 	 --->> 	 0
# sub-10/ses-01/restpost 	 --->> 	 1
# sub-10/ses-01/restpre 	 --->> 	 0
# sub-10/ses-02/restpost 	 --->> 	 0
# sub-10/ses-02/restpre 	 --->> 	 0
# sub-11/ses-01/restpost 	 --->> 	 0
# sub-11/ses-01/restpre 	 --->> 	 0
# sub-11/ses-02/restpost 	 --->> 	 0
# sub-11/ses-02/restpre 	 --->> 	 0
# sub-12/ses-01/restpost 	 --->> 	 0
# sub-12/ses-01/restpre 	 --->> 	 0
# sub-12/ses-02/restpost 	 --->> 	 21
# sub-12/ses-02/restpre 	 --->> 	 0
# sub-13/ses-01/restpost 	 --->> 	 0
# sub-13/ses-01/restpre 	 --->> 	 0
# sub-13/ses-02/restpost 	 --->> 	 0
# sub-13/ses-02/restpre 	 --->> 	 0
# sub-14/ses-01/restpost 	 --->> 	 0
# sub-14/ses-01/restpre 	 --->> 	 0
# sub-14/ses-02/restpost 	 --->> 	 1
# sub-14/ses-02/restpre 	 --->> 	 0
# sub-15/ses-01/restpost 	 --->> 	 1
# sub-15/ses-01/restpre 	 --->> 	 1
# sub-15/ses-02/restpost 	 --->> 	 4
# sub-15/ses-02/restpre 	 --->> 	 0
# sub-16/ses-01/restpost 	 --->> 	 0
# sub-16/ses-01/restpre 	 --->> 	 0
# sub-16/ses-02/restpost 	 --->> 	 4
# sub-16/ses-02/restpre 	 --->> 	 0
# sub-17/ses-01/restpost 	 --->> 	 0
# sub-17/ses-01/restpre 	 --->> 	 0
# sub-17/ses-02/restpost 	 --->> 	 0
# sub-17/ses-02/restpre 	 --->> 	 0
# sub-18/ses-01/restpost 	 --->> 	 0
# sub-18/ses-01/restpre 	 --->> 	 0
# sub-18/ses-02/restpost 	 --->> 	 0
# sub-18/ses-02/restpre 	 --->> 	 0
# sub-19/ses-01/restpost 	 --->> 	 0
# sub-19/ses-01/restpre 	 --->> 	 0
# sub-19/ses-02/restpost 	 --->> 	 2
# sub-19/ses-02/restpre 	 --->> 	 0
# sub-20/ses-01/restpost 	 --->> 	 0
# sub-20/ses-01/restpre 	 --->> 	 0
# sub-20/ses-02/restpost 	 --->> 	 0
# sub-20/ses-02/restpre 	 --->> 	 0
# sub-21/ses-01/restpost 	 --->> 	 0
# sub-21/ses-01/restpre 	 --->> 	 0
# sub-21/ses-02/restpre 	 --->> 	 0
# sub-22/ses-01/restpost 	 --->> 	 0
# sub-22/ses-01/restpre 	 --->> 	 0
# sub-22/ses-02/restpre 	 --->> 	 0
# sub-23/ses-01/restpost 	 --->> 	 0
# sub-23/ses-01/restpre 	 --->> 	 0
# sub-23/ses-02/restpost 	 --->> 	 0
# sub-23/ses-02/restpre 	 --->> 	 0
# sub-24/ses-01/restpost 	 --->> 	 0
# sub-24/ses-01/restpre 	 --->> 	 0
# sub-24/ses-02/restpost 	 --->> 	 3
# sub-24/ses-02/restpre 	 --->> 	 0
# sub-25/ses-01/restpost 	 --->> 	 0
# sub-25/ses-01/restpre 	 --->> 	 0
# sub-25/ses-02/restpost 	 --->> 	 0
# sub-25/ses-02/restpre 	 --->> 	 0
# sub-26/ses-01/restpost 	 --->> 	 0
# sub-26/ses-01/restpre 	 --->> 	 0
# sub-26/ses-02/restpost 	 --->> 	 0
# sub-26/ses-02/restpre 	 --->> 	 0
# sub-27/ses-01/restpost 	 --->> 	 0
# sub-27/ses-01/restpre 	 --->> 	 0
# sub-27/ses-02/restpost 	 --->> 	 0
# sub-27/ses-02/restpre 	 --->> 	 0
# sub-28/ses-01/restpost 	 --->> 	 0
# sub-28/ses-01/restpre 	 --->> 	 0
# sub-28/ses-02/restpost 	 --->> 	 0
# sub-28/ses-02/restpre 	 --->> 	 0
# sub-29/ses-01/restpost 	 --->> 	 0
# sub-29/ses-01/restpre 	 --->> 	 0
# sub-29/ses-02/restpost 	 --->> 	 1
# sub-29/ses-02/restpre 	 --->> 	 0
# sub-30/ses-01/restpost 	 --->> 	 0
# sub-30/ses-01/restpre 	 --->> 	 0
# sub-30/ses-02/restpost 	 --->> 	 17
# sub-30/ses-02/restpre 	 --->> 	 0
# sub-31/ses-01/restpost 	 --->> 	 0
# sub-31/ses-01/restpre 	 --->> 	 0
# sub-31/ses-02/restpost 	 --->> 	 0
# sub-31/ses-02/restpre 	 --->> 	 0
# sub-32/ses-01/restpost 	 --->> 	 0
# sub-32/ses-01/restpre 	 --->> 	 0
# sub-32/ses-02/restpost 	 --->> 	 0
# sub-32/ses-02/restpre 	 --->> 	 0
# sub-33/ses-01/restpost 	 --->> 	 0
# sub-33/ses-01/restpre 	 --->> 	 0
# sub-33/ses-02/restpost 	 --->> 	 0
# sub-33/ses-02/restpre 	 --->> 	 0
# sub-34/ses-01/restpost 	 --->> 	 0
# sub-34/ses-01/restpre 	 --->> 	 0
# sub-34/ses-02/restpost 	 --->> 	 0
# sub-34/ses-02/restpre 	 --->> 	 0
# sub-35/ses-01/restpost 	 --->> 	 0
# sub-35/ses-01/restpre 	 --->> 	 0
# sub-35/ses-02/restpost 	 --->> 	 9
# sub-35/ses-02/restpre 	 --->> 	 0
# sub-36/ses-01/restpost 	 --->> 	 1
# sub-36/ses-01/restpre 	 --->> 	 0
# sub-36/ses-02/restpost 	 --->> 	 1
# sub-36/ses-02/restpre 	 --->> 	 1
# sub-37/ses-01/restpost 	 --->> 	 0
# sub-37/ses-01/restpre 	 --->> 	 0
# sub-37/ses-02/restpost 	 --->> 	 0
# sub-37/ses-02/restpre 	 --->> 	 0
# sub-38/ses-01/restpost 	 --->> 	 0
# sub-38/ses-01/restpre 	 --->> 	 0
# sub-38/ses-02/restpost 	 --->> 	 10
# sub-38/ses-02/restpre 	 --->> 	 0
# sub-39/ses-01/restpost 	 --->> 	 0
# sub-39/ses-01/restpre 	 --->> 	 0
# sub-39/ses-02/restpost 	 --->> 	 0
# sub-39/ses-02/restpre 	 --->> 	 0
# sub-40/ses-01/restpost 	 --->> 	 0
# sub-40/ses-01/restpre 	 --->> 	 0
# sub-40/ses-02/restpost 	 --->> 	 0
# sub-40/ses-02/restpre 	 --->> 	 0
# sub-41/ses-01/restpost 	 --->> 	 0
# sub-41/ses-01/restpre 	 --->> 	 0
# sub-41/ses-02/restpost 	 --->> 	 0
# sub-41/ses-02/restpre 	 --->> 	 0
# sub-42/ses-01/restpost 	 --->> 	 0
# sub-42/ses-01/restpre 	 --->> 	 0
# sub-42/ses-02/restpost 	 --->> 	 0
# sub-42/ses-02/restpre 	 --->> 	 0
# sub-43/ses-01/restpost 	 --->> 	 0
# sub-43/ses-01/restpre 	 --->> 	 0
# sub-43/ses-02/restpre 	 --->> 	 0
# sub-44/ses-01/restpost 	 --->> 	 0
# sub-44/ses-01/restpre 	 --->> 	 0
# sub-44/ses-02/restpost 	 --->> 	 0
# sub-44/ses-02/restpre 	 --->> 	 0
# sub-45/ses-01/restpost 	 --->> 	 0
# sub-45/ses-01/restpre 	 --->> 	 0
# sub-45/ses-02/restpost 	 --->> 	 0
# sub-45/ses-02/restpre 	 --->> 	 0
# sub-46/ses-01/restpost 	 --->> 	 0
# sub-46/ses-01/restpre 	 --->> 	 0
# sub-46/ses-02/restpost 	 --->> 	 0
# sub-46/ses-02/restpre 	 --->> 	 2
# sub-47/ses-01/restpost 	 --->> 	 0
# sub-47/ses-01/restpre 	 --->> 	 0
# sub-47/ses-02/restpost 	 --->> 	 0
# sub-47/ses-02/restpre 	 --->> 	 0
# sub-48/ses-01/restpost 	 --->> 	 0
# sub-48/ses-01/restpre 	 --->> 	 0
# sub-48/ses-02/restpost 	 --->> 	 0
# sub-48/ses-02/restpre 	 --->> 	 0
# sub-49/ses-01/restpost 	 --->> 	 0
# sub-49/ses-01/restpre 	 --->> 	 0
# sub-49/ses-02/restpost 	 --->> 	 0
# sub-49/ses-02/restpre 	 --->> 	 0
# sub-50/ses-01/restpost 	 --->> 	 0
# sub-50/ses-01/restpre 	 --->> 	 0
# sub-50/ses-02/restpost 	 --->> 	 0
# sub-50/ses-02/restpre 	 --->> 	 0
# sub-51/ses-01/restpost 	 --->> 	 0
# sub-51/ses-01/restpre 	 --->> 	 0
# sub-51/ses-02/restpost 	 --->> 	 16
# sub-51/ses-02/restpre 	 --->> 	 0
# sub-52/ses-01/restpost 	 --->> 	 0
# sub-52/ses-01/restpre 	 --->> 	 0
# sub-52/ses-02/restpost 	 --->> 	 0
# sub-52/ses-02/restpre 	 --->> 	 0
# sub-53/ses-01/restpost 	 --->> 	 0
# sub-53/ses-01/restpre 	 --->> 	 0
# sub-53/ses-02/restpost 	 --->> 	 0
# sub-53/ses-02/restpre 	 --->> 	 0
# sub-54/ses-01/restpost 	 --->> 	 0
# sub-54/ses-01/restpre 	 --->> 	 0
# sub-54/ses-02/restpost 	 --->> 	 0
# sub-54/ses-02/restpre 	 --->> 	 0
# sub-55/ses-01/restpost 	 --->> 	 0
# sub-55/ses-01/restpre 	 --->> 	 0
# sub-55/ses-02/restpost 	 --->> 	 0
# sub-55/ses-02/restpre 	 --->> 	 0
# sub-56/ses-01/restpost 	 --->> 	 1
# sub-56/ses-01/restpre 	 --->> 	 0
# sub-56/ses-02/restpost 	 --->> 	 24
# sub-56/ses-02/restpre 	 --->> 	 0
# sub-57/ses-01/restpost 	 --->> 	 0
# sub-57/ses-01/restpre 	 --->> 	 0
# sub-57/ses-02/restpost 	 --->> 	 0
# sub-57/ses-02/restpre 	 --->> 	 0
# sub-58/ses-01/restpost 	 --->> 	 0
# sub-58/ses-01/restpre 	 --->> 	 0
# sub-58/ses-02/restpost 	 --->> 	 0
# sub-58/ses-02/restpre 	 --->> 	 0
# sub-59/ses-01/restpost 	 --->> 	 0
# sub-59/ses-01/restpre 	 --->> 	 0
# sub-59/ses-02/restpost 	 --->> 	 0
# sub-59/ses-02/restpre 	 --->> 	 0
# sub-60/ses-01/restpost 	 --->> 	 0
# sub-60/ses-01/restpre 	 --->> 	 0
# sub-60/ses-02/restpost 	 --->> 	 0
# sub-60/ses-02/restpre 	 --->> 	 0
# sub-61/ses-01/restpost 	 --->> 	 0
# sub-61/ses-01/restpre 	 --->> 	 0
# sub-61/ses-02/restpost 	 --->> 	 0
# sub-61/ses-02/restpre 	 --->> 	 0
# sub-62/ses-01/restpost 	 --->> 	 0
# sub-62/ses-01/restpre 	 --->> 	 0
# sub-62/ses-02/restpost 	 --->> 	 0
# sub-62/ses-02/restpre 	 --->> 	 0
# sub-63/ses-01/restpost 	 --->> 	 0
# sub-63/ses-01/restpre 	 --->> 	 0
# sub-63/ses-02/restpost 	 --->> 	 0
# sub-63/ses-02/restpre 	 --->> 	 0
# sub-64/ses-01/restpost 	 --->> 	 0
# sub-64/ses-01/restpre 	 --->> 	 0
# sub-64/ses-02/restpre 	 --->> 	 0
# sub-65/ses-01/restpost 	 --->> 	 0
# sub-65/ses-01/restpre 	 --->> 	 0
# sub-65/ses-02/restpre 	 --->> 	 0
# sub-66/ses-01/restpost 	 --->> 	 0
# sub-66/ses-01/restpre 	 --->> 	 0
# sub-66/ses-02/restpost 	 --->> 	 0
# sub-66/ses-02/restpre 	 --->> 	 0
# sub-67/ses-01/restpost 	 --->> 	 0
# sub-67/ses-01/restpre 	 --->> 	 0
# sub-67/ses-02/restpost 	 --->> 	 0
# sub-67/ses-02/restpre 	 --->> 	 0
# sub-68/ses-01/restpost 	 --->> 	 0
# sub-68/ses-01/restpre 	 --->> 	 0
# sub-68/ses-02/restpost 	 --->> 	 0
# sub-68/ses-02/restpre 	 --->> 	 0
# sub-69/ses-01/restpost 	 --->> 	 0
# sub-69/ses-01/restpre 	 --->> 	 0
# sub-69/ses-02/restpost 	 --->> 	 2
# sub-69/ses-02/restpre 	 --->> 	 0
# sub-70/ses-01/restpost 	 --->> 	 0
# sub-70/ses-01/restpre 	 --->> 	 0
# sub-70/ses-02/restpost 	 --->> 	 0
# sub-70/ses-02/restpre 	 --->> 	 0
# sub-71/ses-01/restpost 	 --->> 	 0
# sub-71/ses-01/restpre 	 --->> 	 0
# sub-71/ses-02/restpost 	 --->> 	 0
# sub-71/ses-02/restpre 	 --->> 	 0
# sub-72/ses-01/restpost 	 --->> 	 0
# sub-72/ses-01/restpre 	 --->> 	 0
# sub-72/ses-02/restpost 	 --->> 	 0
# sub-72/ses-02/restpre 	 --->> 	 0
# sub-73/ses-01/restpost 	 --->> 	 0
# sub-73/ses-01/restpre 	 --->> 	 0
# sub-73/ses-02/restpost 	 --->> 	 1
# sub-73/ses-02/restpre 	 --->> 	 0
# sub-74/ses-01/restpost 	 --->> 	 0
# sub-74/ses-01/restpre 	 --->> 	 0
# sub-74/ses-02/restpost 	 --->> 	 0
# sub-74/ses-02/restpre 	 --->> 	 0
# sub-75/ses-01/restpost 	 --->> 	 0
# sub-75/ses-01/restpre 	 --->> 	 0
# sub-75/ses-02/restpost 	 --->> 	 0
# sub-75/ses-02/restpre 	 --->> 	 0
# sub-76/ses-01/restpost 	 --->> 	 0
# sub-76/ses-01/restpre 	 --->> 	 0
# sub-76/ses-02/restpost 	 --->> 	 0
# sub-76/ses-02/restpre 	 --->> 	 0
# sub-77/ses-01/restpost 	 --->> 	 0
# sub-77/ses-01/restpre 	 --->> 	 0
# sub-77/ses-02/restpost 	 --->> 	 0
# sub-77/ses-02/restpre 	 --->> 	 0
# sub-78/ses-01/restpost 	 --->> 	 0
# sub-78/ses-01/restpre 	 --->> 	 0
# sub-78/ses-02/restpost 	 --->> 	 0
# sub-78/ses-02/restpre 	 --->> 	 0
# sub-79/ses-01/restpost 	 --->> 	 0
# sub-79/ses-01/restpre 	 --->> 	 0
# sub-79/ses-02/restpost 	 --->> 	 0
# sub-79/ses-02/restpre 	 --->> 	 0
# sub-80/ses-01/restpost 	 --->> 	 0
# sub-80/ses-01/restpre 	 --->> 	 0
# sub-80/ses-02/restpost 	 --->> 	 0
# sub-80/ses-02/restpre 	 --->> 	 0
# sub-81/ses-01/restpost 	 --->> 	 0
# sub-81/ses-01/restpre 	 --->> 	 0
# sub-81/ses-02/restpost 	 --->> 	 0
# sub-81/ses-02/restpre 	 --->> 	 0
# sub-82/ses-01/restpost 	 --->> 	 0
# sub-82/ses-01/restpre 	 --->> 	 0
# sub-82/ses-02/restpost 	 --->> 	 0
# sub-82/ses-02/restpre 	 --->> 	 0
# sub-83/ses-01/restpost 	 --->> 	 0
# sub-83/ses-01/restpre 	 --->> 	 0
# sub-83/ses-02/restpre 	 --->> 	 0
# sub-84/ses-01/restpost 	 --->> 	 0
# sub-84/ses-01/restpre 	 --->> 	 0
# sub-84/ses-02/restpre 	 --->> 	 0

# %%
# Import necessary libraries
import glob
import matplotlib.pyplot as plt
import os
from pathlib import Path

# Define data path
data_path = Path("/mnt/d/Data/Human/ObjectCategorization/analysis2")

# Define subjects to exclude
excluded_subjects = {"sub-56", "sub-51", "sub-38", "sub-35", "sub-30", "sub-12"}  # Add subjects to exclude

# Find all fd_data.txt files
FD_files = list(data_path.glob("sub*/ses-*/func/rest*/motion_assess/fd_data.txt"))

# Initialize list to store framewise displacement data
FD_data = []

# Read and process data from files
for cur_FD in FD_files:
    cur_FD_path = Path(cur_FD)
    subject = cur_FD_path.parts[-6]  # Extracts 'sub-XX' from the path

    if subject in excluded_subjects:
        
        print(f"Skipping {subject}")
        continue  # Skip excluded subjects

    with open(cur_FD, "r") as f:
        FD_data.extend(float(line.strip()) for line in f if line.strip())  # Filters valid numeric values

# Plot histogram
plt.figure(figsize=(8, 6))
plt.hist(FD_data, bins=500, orientation="horizontal", color="skyblue", edgecolor="black")
plt.ylabel("Framewise displacement (mm)")
plt.xlabel("Volume count")

# Apply styling
plt.style.use("seaborn-bright")

# Optional: Save plots
output_dir = data_path / "motion_parameters"
output_dir.mkdir(exist_ok=True)  # Ensure output directory exists
plt.savefig(output_dir / "FD.svg", format="svg", dpi=1200)
plt.savefig(output_dir / "FD.png")

# Show the plot
plt.show()
# Out:
# Skipping sub-12
# Skipping sub-12
# Skipping sub-12
# Skipping sub-12
# Skipping sub-30
# Skipping sub-30
# Skipping sub-30
# Skipping sub-30
# Skipping sub-35
# Skipping sub-35
# Skipping sub-35
# Skipping sub-35
# Skipping sub-38
# Skipping sub-38
# Skipping sub-38
# Skipping sub-38
# Skipping sub-51
# Skipping sub-51
# Skipping sub-51
# Skipping sub-51
# Skipping sub-56
# Skipping sub-56
# Skipping sub-56
# Skipping sub-56
