# %% [markdown]
# # Automated Brain Extraction
# In this code we use recon-all funtion for brain extraction.The recon-all command from FreeSurfer software is used to process MRI scans, performing automated brain extraction and cortical reconstruction.
#
#
# -----------------------------------------------------------
# Script written by Sepideh Tabrik & Mehdi Behroozi
# <br>
# Biopsychology,
# <br>
# Ruhr-University Bochum, Bochum, Germany
# <br>
# (2022.03)
#
# -----------------------------------------------------------

# %%
# %%bash
# # Define SUBJECTS_DIR explicitly
# SUBJECTS_DIR="/mnt/d/Data/Human/ObjectCategorization/analysis2"
#
# # Ensure Freesurfer directory exists
# mkdir -p "$SUBJECTS_DIR/BrainExtraction"
#
# # List relevant T1w files from session 01, extract subject IDs, and process in parallel
# ls "$SUBJECTS_DIR"/sub*/ses-01/anat/*T1w.nii.gz -1 | awk -F'/' '{print $8}' | \
# parallel --jobs 4 recon-all -s "$SUBJECS_DIR/BrainExtraction/anat_ses-01_{}" \
# -i "$SUBJECTS_DIR/{}/ses-01/anat/{}*_ses-01_T1w.nii.gz" -all -qcache -3T
#
# # List relevant T1w filesfrom sesion 02, extract subject IDs, and process in parallel
# ls "$SUBJECTS_DIR"/sub*/ses-02/anat/*T1w.nii.gz -1 | awk -F'/' '{print $8}' | \
# parallel --jobs 4 recon-all -s "$SUBJECTS_DIR/BrainExtraction/anat_ses-02_{}" \
# -i "$SUBJECTS_DIR/{}/ses-02/anat/{}*_ses-02_T1w.nii.gz" -all -qcache -3T
#
#
# #move results to the Freesurfer folder
# mv "$SUBJECTS_DIR"/anat_ses-0* "$SUBJECTS_DIR/BrainExtraction/"

# %% [markdown]
# # Conver Brain Masks to nifti format
# In addition to using recon-all from FreeSurfer for brain reconstruction, we also applied BET from the FSL package to enhance brain extraction, ensuring greater clarity and accuracy in the results.

# %%
import glob
import os
from pathlib import Path

# Define data path
data_path = Path("/mnt/d/Data/Human/ObjectCategorization/analysis2")

# Find anatomical directories
anat_dirs = list(data_path.glob("BrainExtraction/anat*/mri"))

# Process each anatomy directory
for curr_anat in anat_dirs:
    print(f"Change Directory to >> {curr_anat}")
    

    # Ensure the directory exists before changing into it
    if not curr_anat.exists():
        print(f"Skipping: Directory {curr_anat} does not exist!")
        continue
    
    os.chdir(curr_anat)
    
    # Convert brain.mgz to brain.nii.gz
    print("\t1) Converting brain.mgz to brain.nii.gz.")
    os.system(f"mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz")

    # Run BET function from FSL package to get a clear brain mask
    print("\t2) Running BET function from FSL package...")
    os.system("bet brain brain_brain -R -f 0.3 -g 0 -m")

    # Define output path dynamically
    subject = curr_anat.parts[-2].split("_")[-1]
    session = curr_anat.parts[-2].split("_")[-2]
    out_put = data_path / subject / session / "anat" / "mask.nii.gz"

    print(f"\t3) Copying brain mask to {out_put.parent}")
    os.system(f"cp brain_brain_mask.nii.gz {out_put}")

    # Apply brain mask on the original image
    print("\t4) Applying brain mask on original image")
    t1w_image = list(out_put.parent.glob("*T1w.nii.gz"))
    out_put_brain = data_path / subject / session / "anat" / "brain.nii.gz"

    if t1w_image:
        os.system(f"fslmaths {t1w_image[0]} -mul {out_put} {out_put_brain}")
    else:
        print(f"Skipping: No T1w.nii.gz file found in {out_put.parent}")

    # Deleting the nifti files from Freesurfer folders
    os.system('rm -r *nii.gz')
    print("\n")
# Out:
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-01/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.46, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 0, 3.72529e-09)
# j_ras = (0, 2.98023e-08, -1)
# k_ras = (-1.86265e-09, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-01/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-02/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.33, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 9.31323e-10, 1.86265e-09)
# j_ras = (1.86265e-09, -1.49012e-08, -1)
# k_ras = (-9.31323e-10, 1, 1.49012e-08)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-02/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-03/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.27, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 1.06047e-09, -2.91038e-11)
# j_ras = (-2.91038e-11, 0, -1)
# k_ras = (2.66482e-09, 1, 1.49012e-08)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-03/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-04/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.30, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -3.25963e-09, 3.72529e-09)
# j_ras = (3.72529e-09, 0, -1)
# k_ras = (2.32831e-09, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-04/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-05/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.29, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -3.0268e-09, 0)
# j_ras = (-1.86265e-09, 0, -1)
# k_ras = (2.79397e-09, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-05/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-06/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.32, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -2.79397e-09, 0)
# j_ras = (-7.45058e-09, 1.49012e-08, -1)
# k_ras = (6.51926e-09, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-06/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-07/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.17, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -3.31784e-09, 0)
# j_ras = (0, 1.86265e-09, -1)
# k_ras = (3.31784e-09, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-07/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-08/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.38, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 2.32831e-09, 0)
# j_ras = (1.86265e-09, 1.49012e-08, -1)
# k_ras = (-6.0536e-09, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-08/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-09/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.19, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -6.98492e-10, -7.45058e-09)
# j_ras = (-3.72529e-09, 3.72529e-09, -1)
# k_ras = (4.65661e-10, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-09/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-10/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.20, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 6.98492e-10, 0)
# j_ras = (7.45058e-09, 0, -1)
# k_ras = (-9.31323e-10, 1, -3.72529e-09)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-10/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-11/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.19, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 2.21189e-09, 0)
# j_ras = (0, 1.86265e-09, -1)
# k_ras = (5.3551e-09, 1, 1.86265e-09)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-11/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-12/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.36, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -9.31323e-10, 0)
# j_ras = (0, 0, -1)
# k_ras = (-9.31323e-10, 1, -2.98023e-08)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-12/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-13/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.50, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -1.62981e-08, -1.86265e-09)
# j_ras = (1.86265e-09, 2.98023e-08, -1)
# k_ras = (1.39698e-09, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-13/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-14/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.30, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -2.79397e-09, 0)
# j_ras = (0, -1.49012e-08, -1)
# k_ras = (2.79397e-09, 1, -1.49012e-08)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-14/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-15/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.42, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -4.65661e-10, -9.31323e-10)
# j_ras = (0, 0, -1)
# k_ras = (0, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-15/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-16/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.35, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 1.86265e-09, 7.45058e-09)
# j_ras = (0, 0, -1)
# k_ras = (9.31323e-10, 1, -1.49012e-08)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-16/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-17/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.29, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -8.14907e-10, 0)
# j_ras = (0, 0, -1)
# k_ras = (9.31323e-10, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-17/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-18/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.19, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -4.58385e-10, 1.16415e-10)
# j_ras = (1.16415e-10, -7.45058e-09, -1)
# k_ras = (4.43833e-10, 1, -7.45058e-09)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-18/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-19/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.20, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -1.97906e-09, 1.86265e-09)
# j_ras = (0, 0, -1)
# k_ras = (3.49246e-10, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-19/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-20/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.14, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -2.88128e-09, 0)
# j_ras = (1.86265e-09, 9.31323e-10, -1)
# k_ras = (2.91038e-09, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-20/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-21/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.15, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -1.19326e-09, 0)
# j_ras = (0, 0, -1)
# k_ras = (1.19326e-09, 1, 1.86265e-09)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-21/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-22/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.21, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 4.62751e-09, 0)
# j_ras = (0, 0, -1)
# k_ras = (-4.59841e-09, 1, 9.31323e-10)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-22/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-23/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.19, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -6.51926e-09, -3.72529e-09)
# j_ras = (0, 0, -1)
# k_ras = (-9.31323e-10, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-23/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-24/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.32, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -4.65661e-10, -3.72529e-09)
# j_ras = (-7.45058e-09, -1.49012e-08, -1)
# k_ras = (-2.32831e-09, 1, 1.49012e-08)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-24/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-25/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.43, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 0, -1.86265e-09)
# j_ras = (-1.86265e-09, 0, -1)
# k_ras = (0, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-25/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-26/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.26, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -4.65661e-10, 0)
# j_ras = (-3.72529e-09, 0, -1)
# k_ras = (6.98492e-10, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-26/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-27/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.31, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -6.51926e-09, -3.72529e-09)
# j_ras = (-3.72529e-09, -7.45058e-09, -1)
# k_ras = (-8.3819e-09, 1, -7.45058e-09)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-27/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-28/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.39, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -9.31323e-10, 1.39698e-09)
# j_ras = (1.86265e-09, 0, -1)
# k_ras = (1.16415e-09, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-28/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-29/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.32, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 1.39698e-09, 0)
# j_ras = (1.86265e-09, 0, -1)
# k_ras = (-4.65661e-10, 1, -1.49012e-08)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-29/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-30/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.24, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -9.31323e-10, -3.72529e-09)
# j_ras = (0, -3.72529e-09, -1)
# k_ras = (-6.51926e-09, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-30/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-31/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.19, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -1.86265e-09, 0)
# j_ras = (3.72529e-09, 3.72529e-09, -1)
# k_ras = (0, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-31/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-32/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.63, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 7.45058e-09, 1.49012e-08)
# j_ras = (-1.49012e-08, -2.98023e-08, -1)
# k_ras = (-7.45058e-09, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-32/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-33/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.19, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -1.57161e-09, 0)
# j_ras = (1.86265e-09, 0, -1)
# k_ras = (1.5134e-09, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-33/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-34/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.22, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 1.86265e-09, 0)
# j_ras = (1.86265e-09, 7.45058e-09, -1)
# k_ras = (2.32831e-10, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-34/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-35/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.17, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -4.48199e-09, 0)
# j_ras = (1.86265e-09, 0, -1)
# k_ras = (4.48199e-09, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-35/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-36/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.25, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 1.86265e-09, 0)
# j_ras = (0, 7.45058e-09, -1)
# k_ras = (1.86265e-09, 1, -7.45058e-09)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-36/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-37/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.23, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 1.74623e-10, 1.16415e-10)
# j_ras = (0, 0, -1)
# k_ras = (-1.89175e-10, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-37/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-38/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.18, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -4.07454e-10, 0)
# j_ras = (3.72529e-09, 1.86265e-09, -1)
# k_ras = (1.74623e-10, 1, -1.86265e-09)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-38/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-39/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.31, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 1.86265e-09, 0)
# j_ras = (0, 0, -1)
# k_ras = (-9.31323e-10, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-39/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-40/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.19, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 1.39698e-09, 0)
# j_ras = (3.72529e-09, 0, -1)
# k_ras = (2.09548e-09, 1, 3.72529e-09)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-40/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-41/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.26, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -5.47152e-09, -9.31323e-10)
# j_ras = (0, 0, -1)
# k_ras = (5.3551e-09, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-41/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-42/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.18, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 1.10595e-09, 0)
# j_ras = (-1.86265e-09, 9.31323e-10, -1)
# k_ras = (2.61934e-09, 1, -9.31323e-10)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-42/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-43/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.25, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 6.98492e-10, 0)
# j_ras = (0, 7.45058e-09, -1)
# k_ras = (-4.65661e-10, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-43/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-44/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.41, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -2.32831e-10, 0)
# j_ras = (0, -2.98023e-08, -1)
# k_ras = (3.95812e-09, 1, 2.98023e-08)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-44/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-45/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.19, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -2.91038e-09, 1.86265e-09)
# j_ras = (-3.72529e-09, 0, -1)
# k_ras = (-2.67755e-09, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-45/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-46/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.19, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -3.72529e-09, 1.86265e-09)
# j_ras = (-1.86265e-09, 0, -1)
# k_ras = (0, 1, 3.72529e-09)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-46/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-47/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.47, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -9.31323e-10, -3.72529e-09)
# j_ras = (3.72529e-09, 0, -1)
# k_ras = (9.31323e-10, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-47/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-48/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.31, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -5.12227e-09, -7.45058e-09)
# j_ras = (0, 1.86265e-09, -1)
# k_ras = (-9.77889e-09, 1, 1.86265e-09)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-48/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-49/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.29, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 3.25963e-09, 0)
# j_ras = (0, 1.49012e-08, -1)
# k_ras = (3.72529e-09, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-49/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-50/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.13, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -1.13505e-09, 9.31323e-10)
# j_ras = (1.86265e-09, -3.72529e-09, -1)
# k_ras = (4.86034e-09, 1, 1.86265e-09)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-50/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-51/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.24, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 4.65661e-10, 0)
# j_ras = (0, -7.45058e-09, -1)
# k_ras = (4.65661e-10, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-51/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-52/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.23, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 1.86265e-09, 1.86265e-09)
# j_ras = (1.86265e-09, -7.45058e-09, -1)
# k_ras = (-1.86265e-09, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-52/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-53/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.19, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -1.10595e-09, 0)
# j_ras = (3.72529e-09, 0, -1)
# k_ras = (1.04774e-09, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-53/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-54/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.17, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 4.18368e-10, -1.86265e-09)
# j_ras = (1.86265e-09, 0, -1)
# k_ras = (-4.18368e-10, 1, 2.32831e-10)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-54/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-55/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.17, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -3.7835e-10, 0)
# j_ras = (9.31323e-10, 1.86265e-09, -1)
# k_ras = (3.7835e-10, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-55/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-56/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.22, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 2.32831e-09, 3.72529e-09)
# j_ras = (1.11759e-08, -7.45058e-09, -1)
# k_ras = (1.39698e-09, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-56/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-57/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.41, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -6.0536e-09, 9.31323e-10)
# j_ras = (9.31323e-10, -1.49012e-08, -1)
# k_ras = (6.0536e-09, 1, 1.49012e-08)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-57/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-58/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.16, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -3.63798e-09, 0)
# j_ras = (0, 9.31323e-10, -1)
# k_ras = (3.60887e-09, 1, -9.31323e-10)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-58/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-59/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.14, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -3.71983e-10, 0)
# j_ras = (-2.91038e-11, 0, -1)
# k_ras = (-9.27685e-11, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-59/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-60/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.15, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -9.38599e-09, -1.86265e-09)
# j_ras = (0, 0, -1)
# k_ras = (9.39326e-09, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-60/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-61/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.21, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -2.79397e-09, 0)
# j_ras = (0, 0, -1)
# k_ras = (-4.65661e-10, 1, -7.45058e-09)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-61/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-62/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.23, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 3.72529e-09, 0)
# j_ras = (-3.72529e-09, 0, -1)
# k_ras = (0, 1, -7.45058e-09)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-62/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-63/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.24, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -2.64845e-09, -4.65661e-10)
# j_ras = (-4.65661e-10, 0, -1)
# k_ras = (-4.83124e-09, 1, 7.45058e-09)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-63/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-64/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.46, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 3.72529e-09, 0)
# j_ras = (0, 1.49012e-08, -1)
# k_ras = (1.86265e-09, 1, -1.49012e-08)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-64/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-65/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.29, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 4.65661e-09, -6.98492e-10)
# j_ras = (0, -7.45058e-09, -1)
# k_ras = (2.76486e-09, 1, 7.45058e-09)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-65/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-66/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.30, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -4.65661e-10, 0)
# j_ras = (-3.72529e-09, -1.49012e-08, -1)
# k_ras = (0, 1, 1.49012e-08)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-66/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-67/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.38, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -9.31323e-10, 3.72529e-09)
# j_ras = (0, 0, -1)
# k_ras = (9.31323e-10, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-67/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-68/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.39, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -9.31323e-10, 0)
# j_ras = (1.86265e-09, 2.98023e-08, -1)
# k_ras = (-6.51926e-09, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-68/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-69/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.20, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -3.37604e-09, 1.86265e-09)
# j_ras = (0, 7.45058e-09, -1)
# k_ras = (-2.32831e-10, 1, -7.45058e-09)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-69/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-70/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.25, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 1.16415e-10, -9.31323e-10)
# j_ras = (0, 1.49012e-08, -1)
# k_ras = (-3.49246e-10, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-70/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-71/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.29, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 9.31323e-10, 0)
# j_ras = (0, 1.49012e-08, -1)
# k_ras = (1.39698e-09, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-71/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-72/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.25, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 6.98492e-09, 0)
# j_ras = (-3.72529e-09, 0, -1)
# k_ras = (4.65661e-10, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-72/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-73/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.16, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 9.02219e-10, 3.72529e-09)
# j_ras = (0, -9.31323e-10, -1)
# k_ras = (-9.02219e-10, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-73/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-74/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.20, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 4.65661e-10, 0)
# j_ras = (-3.72529e-09, 7.45058e-09, -1)
# k_ras = (0, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-74/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-75/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.17, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 3.8126e-09, -1.86265e-09)
# j_ras = (-3.72529e-09, 9.31323e-10, -1)
# k_ras = (-3.7835e-09, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-75/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-76/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.36, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 1.74623e-09, 2.32831e-09)
# j_ras = (4.65661e-10, 1.49012e-08, -1)
# k_ras = (5.70435e-09, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-76/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-77/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.31, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -4.19095e-09, 0)
# j_ras = (0, -1.49012e-08, -1)
# k_ras = (-3.25963e-09, 1, 1.49012e-08)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-77/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-78/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.18, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 5.82077e-10, 3.72529e-09)
# j_ras = (0, 0, -1)
# k_ras = (3.14321e-09, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-78/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-79/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.34, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -3.25963e-09, 0)
# j_ras = (0, 0, -1)
# k_ras = (-4.19095e-09, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-79/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-80/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.21, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -1.16415e-09, 0)
# j_ras = (0, 0, -1)
# k_ras = (4.65661e-10, 1, 7.45058e-09)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-80/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-81/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.26, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -3.84171e-09, -1.86265e-09)
# j_ras = (0, 0, -1)
# k_ras = (0, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-81/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-82/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.21, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -6.98492e-10, 0)
# j_ras = (0, 0, -1)
# k_ras = (2.32831e-10, 1, -7.45058e-09)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-82/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-83/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.39, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -1.39698e-09, 3.72529e-09)
# j_ras = (1.86265e-09, 1.49012e-08, -1)
# k_ras = (-1.86265e-09, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-83/ses-01/anat
# 	 4) applying brain mask on original image
# Change Directory to >> /mnt/d/Data/Human/ObjectCategorization/analysis/anat_sub-84/mri
# 	 1) converting brain.mgz to brain.nii.gz.
# mri_convert --reslice_like orig/001.mgz brain.mgz brain.nii.gz
# reading from brain.mgz...
# TR=8.21, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, 2.44472e-09, -4.65661e-10)
# j_ras = (-4.65661e-10, 7.45058e-09, -1)
# k_ras = (-6.40284e-10, 1, 0)
# reading template info from volume orig/001.mgz...
# changing data type from uchar to float (noscale = 0)...
# Reslicing using trilinear interpolation
# writing to brain.nii.gz...
# 	 2) running BET function from fsl pckage to have clear brain mask
# 	 3) copying the brain mask to the /mnt/d/Data/Human/ObjectCategorization/analysis/sub-84/ses-01/anat
# 	 4) applying brain mask on original image
