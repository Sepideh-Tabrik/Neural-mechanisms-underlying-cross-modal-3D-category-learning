# %% [markdown]
# # Intensity Normalization
# This script normalizes runs global intensity normalization with grand mean = 10000 across for group analysis.
#
# -----------------------------------------------------------
# Script written by Sepideh Tabrik & Mehdi Behroozi
# <br>
# Biopsychology,
# <br>
# Ruhr-University Bochum, Bochum, Germany
# <br>
# (2022.03)
#
# -----------------------------------------------------------

# %%
import glob
import os
import subprocess
from pathlib import Path

# Define data path
data_path = Path("/mnt/d/Data/Human/ObjectCategorization/analysis2")

# Find smoothed BOLD files
bold_dirs = list(data_path.glob("sub*/ses-02/func/run*/*smoothed.nii.gz"))

# Process each BOLD file
for curr_bold in bold_dirs:
    sub_dir = curr_bold.parent  # Use pathlib to get the parent directory
    
    print(f"Current file is: {curr_bold}")

    # Change directory only if it exists
    if sub_dir.exists():
        print(f"\t1) Changing the working directory to {sub_dir}")
        os.chdir(sub_dir)
    else:
        print(f"\tWarning: {sub_dir} does not exist, skipping.")
        continue

    # Calculate median intensity
    print("\t2) Calculating median intensity...")
    try:
        median_intensity = float(subprocess.check_output(f"fslstats {curr_bold.name} -k mean_func_brain_mask.nii.gz -p 50", shell=True).decode().strip())
        print(f"\t\tMedian intensity is {median_intensity}")
    except subprocess.CalledProcessError:
        print(f"\tWarning: Failed to calculate median intensity for {curr_bold}, skipping.")
        continue

    # Intensity Normalization with grand mean = 10000
    print("\t3) Performing intensity normalization...")
    normmean = 10000

    if median_intensity > 0:  # Avoid division by zero
        scaling = normmean / median_intensity
        output_file = sub_dir / f"{curr_bold.stem.split('.')[0]}_intnorm.nii.gz"
        os.system(f"fslmaths {curr_bold.name} -mul {scaling} {output_file}")
        print(f"\t\tSaved normalized file: {output_file}")
    else:
        print(f"\tWarning: Median intensity is zero, skipping normalization.")

    print()
# Out:
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-01/ses-02/func/run-01/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-01/ses-02/func/run-01
# 	2) Calculating median intensity...
# 		Median intensity is 685642.8125
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-01/ses-02/func/run-01/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-01/ses-02/func/run-02/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-01/ses-02/func/run-02
# 	2) Calculating median intensity...
# 		Median intensity is 682283.125
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-01/ses-02/func/run-02/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-01/ses-02/func/run-03/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-01/ses-02/func/run-03
# 	2) Calculating median intensity...
# 		Median intensity is 666605.875
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-01/ses-02/func/run-03/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-01/ses-02/func/run-04/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-01/ses-02/func/run-04
# 	2) Calculating median intensity...
# 		Median intensity is 678102.125
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-01/ses-02/func/run-04/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-01/ses-02/func/run-05/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-01/ses-02/func/run-05
# 	2) Calculating median intensity...
# 		Median intensity is 665890.1875
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-01/ses-02/func/run-05/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-02/ses-02/func/run-01/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-02/ses-02/func/run-01
# 	2) Calculating median intensity...
# 		Median intensity is 684120.875
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-02/ses-02/func/run-01/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-02/ses-02/func/run-02/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-02/ses-02/func/run-02
# 	2) Calculating median intensity...
# 		Median intensity is 670260.375
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-02/ses-02/func/run-02/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-02/ses-02/func/run-03/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-02/ses-02/func/run-03
# 	2) Calculating median intensity...
# 		Median intensity is 652024.125
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-02/ses-02/func/run-03/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-02/ses-02/func/run-04/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-02/ses-02/func/run-04
# 	2) Calculating median intensity...
# 		Median intensity is 646349.6875
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-02/ses-02/func/run-04/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-02/ses-02/func/run-05/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub
bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-07/ses-02/func/run-01
# 	2) Calculating median intensity...
# 		Median intensity is 809537.75
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-07/ses-02/func/run-01/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-07/ses-02/func/run-02/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-07/ses-02/func/run-02
# 	2) Calculating median intensity...
# 		Median intensity is 747321.0625
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-07/ses-02/func/run-02/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-07/ses-02/func/run-03/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-07/ses-02/func/run-03
# 	2) Calculating median intensity...
# 		Median intensity is 804411.4375
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-07/ses-02/func/run-03/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-07/ses-02/func/run-04/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-07/ses-02/func/run-04
# 	2) Calculating median intensity...
# 		Median intensity is 839084.8125
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-07/ses-02/func/run-04/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-07/ses-02/func/run-05/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-07/ses-02/func/run-05
# 	2) Calculating median intensity...
# 		Median intensity is 854504.625
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-07/ses-02/func/run-05/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-08/ses-02/func/run-01/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-08/ses-02/func/run-01
# 	2) Calculating median intensity...
# 		Median intensity is 686011.625
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-08/ses-02/func/run-01/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-08/ses-02/func/run-02/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-08/ses-02/func/run-02
# 	2) Calculating median intensity...
# 		Median intensity is 680803.875
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-08/ses-02/func/run-02/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-08/ses-02/func/run-03/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-08/ses-02/func/run-03
# 	2) Calculating median intensity...
# 		Median intensity is 672151.4375
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-08/ses-02/func/run-03/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-08/ses-02/func/run-04/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-08/ses-02/func/run-04
# 	2) Calculating median intensity...
# 		Median intensity is 668020.4375
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-08/ses-02/func/run-04/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-08/ses-02/func/run-05/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-08/ses-02/func/run-05
# 	2) Calculating median intensity...
# 		Median intensity is 670032.3125
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-08/ses-02/func/run-05/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-09/ses-02/func/run-01/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-09/ses-02/func/run-01
# 	2) Calculating median intensity...
# 		Median intensity is 634105.375
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-09/ses-02/func/run-01/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-09/ses-02/func/run-02/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-09/ses-02/func/run-02
# 	2) Calculating median intensity...
# 		Median intensity is 625346.625
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-09/ses-02/func/run-02/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-09/ses-02/func/run-03/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-09/ses-02/func/run-03
# 	2) Calculating median intensity...
# 		Median intensity is 619908.6875
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-09/ses-02/func/run-03/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-09/ses-02/func/run-04/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-09/ses-02/func/run-04
# 	2) Calculating median intensity...
# 		Median intensity is 621031.0
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-09/ses-02/func/run-04/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-09/ses-02/func/run-05/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-09/ses-02/func/run-05
# 	2) Calculating median intensity...
# 		Median intensity is 625762.75
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-09/ses-02/func/run-05/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-10/ses-02/func/run-01/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-10/ses-02/func/run-01
# 	2) Calculating median intensity...
# 		Median intensity is 459798.40625
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-10/ses-02/func/run-01/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-10/ses-02/func/run-02/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-10/ses-02/func/run-02
# 	2) Calculating median intensity...
# 		Median intensity is 450484.9375
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-10/ses-02/func/run-02/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-10/ses-02/func/run-03/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-10/ses-02/func/run-03
# 	2) Calculating median intensity...
# 		Median intensity is 450872.0
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-10/ses-02/func/run-03/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-10/ses-02/func/run-04/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-10/ses-02/func/run-04
# 	2) Calculating median intensity...
# 		Median intensity is 465583.96875
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-10/ses-02/func/run-04/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-10/ses-02/func/run-05/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-10/ses-02/func/run-05
# 	2) Calculating median intensity...
# 		Median intensity is 453891.40625
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-10/ses-02/func/run-05/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-11/ses-02/func/run-01/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-11/ses-02/func/run-01
# 	2) Calculating median intensity...
# 		Median intensity is 454551.90625
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-11/ses-02/func/run-01/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-11/ses-02/func/run-02/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub
bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-19/ses-02/func/run-04/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-19/ses-02/func/run-04
# 	2) Calculating median intensity...
# 		Median intensity is 399543.84375
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-19/ses-02/func/run-04/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-19/ses-02/func/run-05/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-19/ses-02/func/run-05
# 	2) Calculating median intensity...
# 		Median intensity is 394622.59375
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-19/ses-02/func/run-05/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-20/ses-02/func/run-01/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-20/ses-02/func/run-01
# 	2) Calculating median intensity...
# 		Median intensity is 433770.9375
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-20/ses-02/func/run-01/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-20/ses-02/func/run-02/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-20/ses-02/func/run-02
# 	2) Calculating median intensity...
# 		Median intensity is 428800.71875
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-20/ses-02/func/run-02/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-20/ses-02/func/run-03/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-20/ses-02/func/run-03
# 	2) Calculating median intensity...
# 		Median intensity is 266172.28125
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-20/ses-02/func/run-03/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-20/ses-02/func/run-04/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-20/ses-02/func/run-04
# 	2) Calculating median intensity...
# 		Median intensity is 165577.046875
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-20/ses-02/func/run-04/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-20/ses-02/func/run-05/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-20/ses-02/func/run-05
# 	2) Calculating median intensity...
# 		Median intensity is 427751.71875
# ...
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-78/ses-02/func/run-03/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-78/ses-02/func/run-03
# 	2) Calculating median intensity...
# 		Median intensity is 413165.59375
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-78/ses-02/func/run-03/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-78/ses-02/func/run-04/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-78/ses-02/func/run-04
# 	2) Calculating median intensity...
# 		Median intensity is 401184.5
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-78/ses-02/func/run-04/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-78/ses-02/func/run-05/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-78/ses-02/func/run-05
# 	2) Calculating median intensity...
# 		Median intensity is 395064.5625
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-78/ses-02/func/run-05/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-79/ses-02/func/run-01/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-79/ses-02/func/run-01
# 	2) Calculating median intensity...
# 		Median intensity is 500297.25
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-79/ses-02/func/run-01/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-79/ses-02/func/run-02/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-79/ses-02/func/run-02
# 	2) Calculating median intensity...
# 		Median intensity is 504329.25
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-79/ses-02/func/run-02/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-79/ses-02/func/run-03/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-79/ses-02/func/run-03
# 	2) Calculating median intensity...
# 		Median intensity is 500372.09375
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-79/ses-02/func/run-03/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-79/ses-02/func/run-04/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-79/ses-02/func/run-04
# 	2) Calculating median intensity...
# 		Median intensity is 504358.9375
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-79/ses-02/func/run-04/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-79/ses-02/func/run-05/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-79/ses-02/func/run-05
# 	2) Calculating median intensity...
# 		Median intensity is 496473.625
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-79/ses-02/func/run-05/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-80/ses-02/func/run-01/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-80/ses-02/func/run-01
# 	2) Calculating median intensity...
# 		Median intensity is 392201.8125
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-80/ses-02/func/run-01/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-80/ses-02/func/run-02/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-80/ses-02/func/run-02
# 	2) Calculating median intensity...
# 		Median intensity is 394146.15625
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-80/ses-02/func/run-02/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-80/ses-02/func/run-03/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-80/ses-02/func/run-03
# 	2) Calculating median intensity...
# 		Median intensity is 383530.71875
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-80/ses-02/func/run-03/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-80/ses-02/func/run-04/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-80/ses-02/func/run-04
# 	2) Calculating median intensity...
# 		Median intensity is 382505.21875
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-80/ses-02/func/run-04/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-80/ses-02/func/run-05/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-80/ses-02/func/run-05
# 	2) Calculating median intensity...
# 		Median intensity is 379223.53125
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-80/ses-02/func/run-05/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-81/ses-02/func/run-01/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-81/ses-02/func/run-01
# 	2) Calculating median intensity...
# 		Median intensity is 615663.9375
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-81/ses-02/func/run-01/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-81/ses-02/func/run-02/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-81/ses-02/func/run-02
# 	2) Calculating median intensity...
# 		Median intensity is 713345.1875
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-81/ses-02/func/run-02/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-81/ses-02/func/run-03/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-81/ses-02/func/run-03
# 	2) Calculating median intensity...
# 		Median intensity is 656208.375
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-81/ses-02/func/run-03/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-81/ses-02/func/run-04/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-81/ses-02/func/run-04
# 	2) Calculating median intensity...
# 		Median intensity is 616742.875
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-81/ses-02/func/run-04/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-81/ses-02/func/run-05/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-81/ses-02/func/run-05
# 	2) Calculating median intensity...
# 		Median intensity is 380140.875
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-81/ses-02/func/run-05/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-82/ses-02/func/run-01/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-82/ses-02/func/run-01
# 	2) Calculating median intensity...
# 		Median intensity is 721059.5625
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-82/ses-02/func/run-01/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-82/ses-02/func/run-02/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-82/ses-02/func/run-02
# 	2) Calculating median intensity...
# 		Median intensity is 714600.25
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-82/ses-02/func/run-02/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-82/ses-02/func/run-03/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-82/ses-02/func/run-03
# 	2) Calculating median intensity...
# 		Median intensity is 711727.5625
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-82/ses-02/func/run-03/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-82/ses-02/func/run-04/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-82/ses-02/func/run-04
# 	2) Calculating median intensity...
# 		Median intensity is 705931.1875
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-82/ses-02/func/run-04/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-82/ses-02/func/run-05/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-82/ses-02/func/run-05
# 	2) Calculating median intensity...
# 		Median intensity is 703242.25
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-82/ses-02/func/run-05/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-83/ses-02/func/run-01/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-83/ses-02/func/run-01
# 	2) Calculating median intensity...
# 		Median intensity is 690963.9375
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-83/ses-02/func/run-01/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-83/ses-02/func/run-02/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-83/ses-02/func/run-02
# 	2) Calculating median intensity...
# 		Median intensity is 682646.0
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-83/ses-02/func/run-02/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-83/ses-02/func/run-03/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-83/ses-02/func/run-03
# 	2) Calculating median intensity...
# 		Median intensity is 677968.875
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-83/ses-02/func/run-03/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-83/ses-02/func/run-04/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-83/ses-02/func/run-04
# 	2) Calculating median intensity...
# 		Median intensity is 678048.1875
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-83/ses-02/func/run-04/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-83/ses-02/func/run-05/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-83/ses-02/func/run-05
# 	2) Calculating median intensity...
# 		Median intensity is 261338.078125
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-83/ses-02/func/run-05/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-84/ses-02/func/run-01/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-84/ses-02/func/run-01
# 	2) Calculating median intensity...
# 		Median intensity is 689761.5625
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-84/ses-02/func/run-01/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-84/ses-02/func/run-02/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-84/ses-02/func/run-02
# 	2) Calculating median intensity...
# 		Median intensity is 666884.9375
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-84/ses-02/func/run-02/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-84/ses-02/func/run-03/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-84/ses-02/func/run-03
# 	2) Calculating median intensity...
# 		Median intensity is 259395.703125
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-84/ses-02/func/run-03/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-84/ses-02/func/run-04/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-84/ses-02/func/run-04
# 	2) Calculating median intensity...
# 		Median intensity is 664871.125
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-84/ses-02/func/run-04/bold_mcf_st_smoothed_intnorm.nii.gz
#
# Current file is: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-84/ses-02/func/run-05/bold_mcf_st_smoothed.nii.gz
# 	1) Changing the working directory to /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-84/ses-02/func/run-05
# 	2) Calculating median intensity...
# 		Median intensity is 663480.6875
# 	3) Performing intensity normalization...
# 		Saved normalized file: /mnt/d/Data/Human/ObjectCategorization/analysis2/sub-84/ses-02/func/run-05/bold_mcf_st_smoothed_intnorm.nii.gz
